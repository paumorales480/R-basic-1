# %% [markdown]
# #### Script para descargar bases de INEGI de forma automática y no se me olvide!!

# %%
# Limpiamos el entorno de trabajo
rm(list = ls())

# %%
#Cargamos las librerías necesarias! (Otro día tendré que hacer un archivo para explicar las librerías que más uso)
if(!require('pacman')) install.packages('pacman')
pacman::p_load(tidyverse, srvyr, utils)
# Out:
# Loading required package: pacman

# %%
# URL del archivo ZIP 
url_zip <- "https://www.inegi.org.mx/contenidos/programas/enigh/nc/2024/microdatos/enigh2024_ns_poblacion_csv.zip"

# %%
# Crear un directorio temporal para guardar el ZIP
temp_dir <- tempdir()
zip_path <- file.path(temp_dir, "archivo.zip")

# %%
# Descargar el ZIP
download.file(url_zip, destfile = zip_path, mode = "wb")

# Descomprimir los archivos dentro del ZIP al mismo directorio temporal
unzip(zip_path, exdir = temp_dir)

# Ver qué archivos se extrajeron
list.files(temp_dir)
# Out:
# [1] "archivo.zip"   "poblacion.csv"

# %%
# Localizar el CSV (ajusta el nombre según el archivo que haya dentro)
csv_file <- list.files(temp_dir, pattern = "poblacion.csv$", full.names = TRUE)[1]   #Aquí solo se modifica el nombre del archivo,
#dependiendo del que quiera :)

# Leer el CSV
datos <- read_csv(csv_file)
# Out:
# Warning message:
# "One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)"
# Rows: 308598 Columns: 185
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (38): folioviv, numren, madre_id, padre_id, disc_ver, disc_oir, disc_br...
# dbl (116): foliohog, parentesco, sexo, edad, madre_hog, padre_hog, pais_nac,...
# lgl  (31): otorg_c, forma_c, inscr_8, noatenc_4, noatenc_6, noatenc_7, noate...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
names(datos)
# Out:
#   [1] "folioviv"   "foliohog"   "numren"     "parentesco" "sexo"
#   [6] "edad"       "madre_hog"  "madre_id"   "padre_hog"  "padre_id"
#  [11] "pais_nac"   "afrod"      "disc_ver"   "disc_oir"   "disc_brazo"
#  [16] "disc_camin" "disc_apren" "disc_vest"  "disc_habla" "disc_acti"
#  [21] "edu_ini"    "no_asis"    "hablaind"   "lenguaind"  "hablaesp"
#  [26] "comprenind" "etnia"      "alfabetism" "asis_esc"   "no_asisb"
#  [31] "nivel"      "grado"      "tipoesc"    "tiene_b"    "otorg_b"
#  [36] "forma_b"    "tiene_c"    "otorg_c"    "forma_c"    "nivelaprob"
#  [41] "gradoaprob" "antec_esc"  "residencia" "edo_conyug" "pareja_hog"
#  [46] "conyuge_id" "segsoc"     "ss_aa"      "ss_mm"      "redsoc_1"
#  [51] "redsoc_2"   "redsoc_3"   "redsoc_4"   "redsoc_5"   "redsoc_6"
#  [56] "hor_1"      "min_1"      "usotiempo1" "hor_2"      "min_2"
#  [61] "usotiempo2" "hor_3"      "min_3"      "usotiempo3" "hor_4"
#  [66] "min_4"      "usotiempo4" "hor_5"      "min_5"      "usotiempo5"
#  [71] "hor_6"      "min_6"      "usotiempo6" "hor_7"      "min_7"
#  [76] "usotiempo7" "hor_8"      "min_8"      "usotiempo8" "inst_1"
#  [81] "inst_2"     "inst_3"     "inst_4"     "inst_5"     "inst_6"
#  [86] "inst_7"     "inst_8"     "inst_9"     "atemed"     "inscr_1"
#  [91] "inscr_2"    "inscr_3"    "inscr_4"    "inscr_5"    "inscr_6"
#  [96] "inscr_7"    "inscr_8"    "prob_anio"  "prob_mes"   "prob_sal"
# [101] "aten_sal"   "servmed_1"  "servmed_2"  "servmed_3"  "servmed_4"
# [106] "servmed_5"  "servmed_6"  "servmed_7"  "servmed_8"  "servmed_9"
# [111] "servmed_10" "servmed_11" "hh_lug"     "mm_lug"     "hh_esp"
# [116] "mm_esp"     "pagoaten_1" "pagoaten_2" "pagoaten_3" "pagoaten_4"
# [121] "pagoaten_5" "pagoaten_6" "pagoaten_7" "noatenc_1"  "noatenc_2"
# [126] "noatenc_3"  "noatenc_4"  "noatenc_5"  "noatenc_6"  "noatenc_7"
# [131] "noatenc_8"  "noatenc_9"  "noatenc_10" "noatenc_11" "noatenc_12"
# [136] "noatenc_13" "noatenc_14" "noatenc_15" "noatenc_16" "norecib_1"
# [141] "norecib_2"  "norecib_3"  "norecib_4"  "norecib_5"  "norecib_6"
# [146] "norecib_7"  "norecib_8"  "norecib_9"  "norecib_10" "norecib_11"
# [151] "razon_1"    "razon_2"    "razon_3"    "razon_4"    "razon_5"
# [156] "razon_6"    "razon_7"    "razon_8"    "razon_9"    "razon_10"
# [161] "razon_11"   "diabetes"   "pres_alta"  "peso"       "segvol_1"
# [166] "segvol_2"   "segvol_3"   "segvol_4"   "segvol_5"   "segvol_6"
# [171] "segvol_7"   "hijos_viv"  "hijos_mue"  "hijos_sob"  "trabajo_mp"
# [176] "motivo_aus" "act_pnea1"  "act_pnea2"  "num_trabaj" "c_futuro"
# [181] "ct_futuro"  "entidad"    "est_dis"    "upm"        "factor"

# %% [markdown]
# #### Ya descargué mis datos!. ¿Cómo uso el diseño muestral de una encuesta?

# %%
#Vamos a suponer que quiero medir el número de hombres y mujeres en la CDMX de 15 a 60 años

#Limpio mis datos! 

datos<- datos %>%
    select(sexo, edad, entidad, upm, factor, est_dis)%>%
    filter(entidad == '09') %>%
    mutate(edad_objetivo= case_when(
        edad >= 15 & edad <=60 ~ 1, 
        TRUE ~ 0
    )) 


head(datos)
# Out:
#   sexo edad entidad upm     factor est_dis edad_objetivo
# 1 2    75   09      0003222 1182   166     0
# 2 1    48   09      0003222 1182   166     1
# 3 1    40   09      0003222 1182   166     1
# 4 2    40   09      0003222 1182   166     1
# 5 2    23   09      0003222 1182   166     1
# 6 1    13   09      0003222 1182   166     0

# %%
# Ya que tenemos el indicador ... (sonido de tambores)
# Establecemos el diseño muestral!

dm <- datos %>%
    as_survey_design(ids= upm, strata=est_dis, weights= factor)

# %%
dato <- dm %>%
  group_by(sexo) %>%
  summarise(
    total_poblacion = survey_total(vartype = "cv"),  # total ponderado
    total_edad_objetivo = survey_total(edad_objetivo, vartype = "cv")  # total 15–60
  ) %>%
  mutate(
    porcentaje_edad_objetivo = (total_edad_objetivo / total_poblacion) * 100,
    sexo = recode(sexo, `1` = "Hombres", `2` = "Mujeres")
  )
dato
# Out:
#   sexo    total_poblacion total_poblacion_cv total_edad_objetivo
# 1 Hombres 4356216         0.02282543         2898767
# 2 Mujeres 5025039         0.01938147         3279843
#   total_edad_objetivo_cv porcentaje_edad_objetivo
# 1 0.02655506             66.54323
# 2 0.02292302             65.27000

# %%
#Jugando ando 
#Total de la pob de cdmx
pob_tot_cdmx <- dm %>%
    summarise(pob_tot_cdmx = survey_total(vartype = "cv"))
print("Total de la población de la CDMX")
pob_tot_cdmx
# Out:
# [1] "Total de la población de la CDMX"
#   pob_tot_cdmx pob_tot_cdmx_cv
# 1 9381255      0.01799828

# %%
#Cálculo del total de población CDMX
total_cdmx <- dm %>%
  summarise(total_cdmx = survey_total(vartype = NULL)) %>%
  pull(total_cdmx)

# Cálculo por sexo (respecto al total CDMX)
dato <- dm %>%
  group_by(sexo) %>%
  summarise(
    total_edad_objetivo = survey_total(edad_objetivo, vartype = "cv")
  ) %>%
  mutate(
    porcentaje_sobre_total = (total_edad_objetivo / total_cdmx) * 100,
    sexo = recode(sexo, `1` = "Hombres", `2` = "Mujeres"))

#Ver resultados
dato
# Out:
#   sexo    total_edad_objetivo total_edad_objetivo_cv porcentaje_sobre_total
# 1 Hombres 2898767             0.02655506             30.89957
# 2 Mujeres 3279843             0.02292302             34.96167

# %%
#Porcentaje de hombres y mujeres en la cdmx (sin filtro de edad)
hom_muj <- dm %>%
    group_by(sexo)%>%
    summarise(total=survey_total(vartype = "cv"))%>%
    mutate(porcentaje=(total/total_cdmx * 100),
            sexo = recode(sexo, `1` = "Hombres", `2` = "Mujeres"))
print("¡Valores!:")
hom_muj
# Out:
# [1] "¡Valores!:"
#   sexo    total   total_cv   porcentaje
# 1 Hombres 4356216 0.02282543 46.43532
# 2 Mujeres 5025039 0.01938147 53.56468
